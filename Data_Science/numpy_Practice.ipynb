# %%
import numpy as np
a= np.array([1,2,3,4,5])
print(a)
# Out:
# [1 2 3 4 5]

# %%
b = np.array([1,2,3,4,5])
print(b.ndim)
print(a+b) # adding two numpy array
# Out:
# 1
# [ 2  4  6  8 10]

# %%
c= np.array([[1,2,3],[4,5,6]])
print(c.shape)
print(c.ndim) # it is to print dimension of array
# Out:
# (2, 3)
# 2

# %%
print(b.sum()) # print the sum of no. in variable b
print(c.sum()) # print the sum of no. in variable c

print(b.mean()) # print the mean

print(b.std()) # print the standard deviation

print(b.any())
# Out:
# 15
# 21
# 3.0
# 1.4142135623730951
# True

# %%
np.cross(a,c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Priyanshu\Desktop\Python Data Science\Data_Science\numpy_Practice.ipynb Cell 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Priyanshu/Desktop/Python%20Data%20Science/Data_Science/numpy_Practice.ipynb#ch0000004?line=0'>1</a> np.cross(a,c)
#
# File <__array_function__ internals>:180, in cross(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\numpy\core\numeric.py:1613, in cross(a, b, axisa, axisb, axisc, axis)
#    1610 msg = ("incompatible dimensions for cross product\n"
#    1611        "(dimension must be 2 or 3)")
#    1612 if a.shape[-1] not in (2, 3) or b.shape[-1] not in (2, 3):
# -> 1613     raise ValueError(msg)
#    1615 # Create the output array
#    1616 shape = broadcast(a[..., 0], b[..., 0]).shape
#
# ValueError: incompatible dimensions for cross product
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

a= np.arange(1,15,3) 
b= np.arange(2,20,4)
c= np.arange(0,10,2)

print(a)
print(b)
print(c)

plt.figure(figsize=(25,5),layout='constrained')
plt.plot(a,linewidth=3,label='a',)
plt.legend(loc='upper left',fontsize=16)
plt.plot(b,linewidth=3, label='b',)
plt.legend(loc='upper left',fontsize=16)
plt.plot(c,linewidth=3,label='c',)
plt.legend(loc='upper left',fontsize=16)

plt.title('DATA',size=30)
plt.xlabel('X-axis data',size=25)
plt.ylabel('y-axis data',size=25)
# Out:
# [ 1  4  7 10 13]
# [ 2  6 10 14 18]
# [0 2 4 6 8]
# Text(0, 0.5, 'y-axis data')

# %%
x = np.linspace(0, 2, 100)  # Sample data.

# Note that even in the OO-style, we use `.pyplot.figure` to create the Figure.
fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.plot(x, x, label='linear')  # Plot some data on the axes.
ax.plot(x, x**2, label='quadratic')  # Plot more data on the axes...
ax.plot(x, x**3, label='cubic')  # ... and some more.
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.
ax.legend();  # Add a legend.
#plt.savefig('pract_graph.png')

# %%
from Function import My_numpy_function

data = [180,172,178,185,190,192,200,210,190]
My_numpy_function.osd(data)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Priyanshu\Desktop\Python Data Science\Data_Science\numpy_Practice.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Priyanshu/Desktop/Python%20Data%20Science/Data_Science/numpy_Practice.ipynb#ch0000007?line=0'>1</a> from Function import My_numpy_function
#       <a href='vscode-notebook-cell:/c%3A/Users/Priyanshu/Desktop/Python%20Data%20Science/Data_Science/numpy_Practice.ipynb#ch0000007?line=2'>3</a> data = [180,172,178,185,190,192,200,210,190]
#       <a href='vscode-notebook-cell:/c%3A/Users/Priyanshu/Desktop/Python%20Data%20Science/Data_Science/numpy_Practice.ipynb#ch0000007?line=3'>4</a> My_numpy_function.osd(data)
#
# ModuleNotFoundError: No module named 'Function'
