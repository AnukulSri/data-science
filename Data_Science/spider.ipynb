# %%
from dputils import scrape as sc
import pandas as pd

# %%
query = 'mobiles'
url=f'https://www.amazon.in/s?k={query}'
print(url)
soup = sc.get_webpage_data(url)
# Out:
# https://www.amazon.in/s?k=mobiles
# Error occurred during loading data. Trying to use cache server https://fake-useragent.herokuapp.com/browsers/0.1.11
# Traceback (most recent call last):
#   File "C:\Users\Priyanshu\AppData\Roaming\Python\Python39\site-packages\fake_useragent\utils.py", line 154, in load
#     for item in get_browsers(verify_ssl=verify_ssl):
#   File "C:\Users\Priyanshu\AppData\Roaming\Python\Python39\site-packages\fake_useragent\utils.py", line 99, in get_browsers
#     html = html.split('<table class="w3-table-all notranslate">')[1]
# IndexError: list index out of range

# %%
# target
target = {'tag':'div', 'attrs':{ 'class': 's-main-slot s-result-list s-search-results sg-row'}}
# items
items = {'tag':'div', 'attrs':{ 'class': 's-result-item'}}
#image
delivery={'tag':'div','attrs':{'class':'a-row s-align-children-center'}}
# heading
title = {'tag':'h2','attrs':{'class':'a-size-mini a-spacing-none a-color-base s-line-clamp-2'}}
# price
price = {'tag':'span','attrs':{'class':'a-price-whole'}}

rating = {'tag':'div','attrs':{'class':'a-section a-spacing-none a-spacing-top-micro'}}

# %%
output = sc.extract_many(soup,
        target=target, 
        items=items,
        title=title, 
        price=price, 
        delivery = delivery,
        rating=rating)
# Out:
# 36 items found
# Item skipped at index: 0
# Item skipped at index: 1
# Item skipped at index: 5
# Item skipped at index: 7
# Item skipped at index: 8
# Item skipped at index: 9
# Item skipped at index: 10
# Item skipped at index: 11
# Item skipped at index: 12
# Item skipped at index: 13
# Item skipped at index: 31
# Item skipped at index: 32
# Item skipped at index: 33
# Item skipped at index: 34
# Item skipped at index: 35
# All items extracted

# %%
df= pd.DataFrame(output)
df
# Out:
#                                                 title     price  \
# 0   Samsung Galaxy M33 5G (Mystique Green, 8GB, 12...    20,499
# 1   Samsung Galaxy Z Flip4 5G (Pink Gold, 8GB RAM,...    92,998
# 2   Redmi 9A Sport (Coral Green, 2GB RAM, 32GB Sto...     6,999
# 3   Redmi 9 Activ (Coral Green, 4GB RAM, 64GB Stor...     8,999
# 4   Xiaomi Redmi 10 Prime (Phantom Black 4GB RAM 6...    10,999
# 5   OPPO A31 (Mystery Black, 6GB RAM, 128GB Storag...    11,990
# 6   JioPhone Next 32 GB ROM, 2 GB RAM, Blue Smartp...     4,630
# 7   Redmi Note 10S (Frost White, 6GB RAM, 64GB Sto...    12,999
# 8   Redmi 10 Prime (Phantom Black 6GB RAM 128GB RO...    13,499
