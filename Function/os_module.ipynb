# %%
import os

# %% [markdown]
# # Os function

# %%
os.getcwd() # this will show the current open folder's path
# Out:
# 'c:\\Users\\Priyanshu\\Desktop\\Python Data Science'

# %%
files = os.listdir() # this function will show the files in that folder
print(files)
# Out:
# ['.git', '.gitattributes', '.gitignore', 'basics', 'breakcontinue.ipynb', 'builtinstringfun.ipynb', 'ControlFlow.ipynb', 'count.ipynb', 'dictionary.ipynb', 'Enumerate.ipynb', 'evenodd.ipynb', 'File_Handling.ipynb', 'forElseLoop.ipynb', 'forLoop_question', 'list.ipynb', 'Loops.ipynb', 'Method2.ipynb', 'Methods.ipynb', 'os_module.ipynb', 'primenumber.ipynb', 'pythagorstheorem.ipynb', 'range.ipynb', 'sample.ipynb', 'Sets.ipynb', 'simpleInterest.ipynb', 'sizeofword.ipynb', 'slicingInString.ipynb', 'string.ipynb', 'String_Que', 'String_question.ipynb', 'sum.ipynb', 'Tuple_Details.ipynb', 'Turtle.py', 'turtleCharacter.py', 'TurtleCircle.py', 'TurtlecolouredShapes.py', 'turtleConcentricCircle.py', 'turtleConcentricsquare.py', 'TurtleFlower.py', 'Turtlegotofunc.py', 'turtleHexagonalpattern.py', 'turtleOctagon.py', 'turtlepentagon.py', 'turtleRandomPattern.py', 'TurtlerQuadrant.py', 'TurtleShellpattern.py', 'turtleSquare.py', 'TurtleStarPattern.py', 'writing_Content.txt', 'writing_text2.txt']
# ...

# %%
filesX = os.listdir('C:/Windows/System32/') # this will print the files present in system32.
print (filesX)
# Out:
# ['0409', '1028', '1029', '1031', '1033', '1036', '1040', '1041', '1042', '1045', '1046', '1049', '1055', '2052', '3082', '@edptoastimage.png', '@language_notification_icon.png', '@NotifierToastIcon.png', '@optionalfeatures.png', '@TileEmpty1x1Image.png', '@WiFiNotificationIcon.png', 'aadauthhelper.dll', 'aadcloudap.dll', 'aadtb.dll', 'AboveLockAppHost.dll', 'accessibilitycpl.dll', 'accountaccessor.dll', 'AccountsControlInternal.dll', 'AccountsRt.dll', 'ACCTRES.dll', 'acledit.dll', 'aclui.dll', 'acmigration.dll', 'ACPBackgroundManagerPolicy.dll', 'AcpiServiceVnA64.dll', 'acppage.dll', 'acproxy.dll', 'ActionCenter.dll', 'ActionCenterCPL.dll', 'ActionQueue.dll', 'ActivationClient.dll', 'ActivationManager.dll', 'activeds.dll', 'activeds.tlb', 'ActiveSyncCsp.dll', 'ActiveSyncProvider.dll', 'actxprxy.dll', 'acu.exe', 'adalsql.dll', 'AddressParser.dll', 'adhapi.dll', 'adhsvc.dll', 'AdmTmpl.dll', 'adprovider.dll', 'adrclient.dll', 'adsldp.dll', 'adsldpc.dll', 'adsmsext.dll', 'adsnt.dll', 'ad
# ...

# %%
len(filesX)
# Out:
# 4056

# %%
dll = 0
for file in filesX:
    if file.endswith('.dll'):
        dll += 1
print(f'the system has {dll} dlls')
# Out:
# the system has 2831 dlls

# %% [markdown]
# # Creating Folder

# %%
os.mkdir('basics') # by using mkdir we can create folder

# %%
os.mkdir('faltu_folder')

# %%
os.rmdir('faltu_folder') # by using rmdir we can delete a folder but folder cannot be deleted if there are files in a folder.

# %%
os.path.isdir('basics') # isdir is used to check that folder is present or not
# Out:
# True

# %%
for item in files:
    if os.path.isdir(item): # here it will print all the folders
        print(f'{item} is directory') # directory means folder
# Out:
# .git is directory
# basics is directory
# forLoop_question is directory
# String_Que is directory

# %%
s= os.path.getsize(r'C:\Users\Priyanshu\Downloads\Project_IGI_RIP') # this will print the size of a file
# Out:
# 0

# %%
# to find the size of file in mb

s/(1024*1024)
# Out:
# 0.0

# %%
files = os.listdir()
for item in files:
    if os.path.isfile(item):
        sz = os.path.getsize(item)
        print(f'{item.ljust(25)} | {sz/1024 :.1f} kb') # sz/1024 this done to print the file size in kb
# Out:
# .gitattributes            | 0.1 kb
# .gitignore                | 2.8 kb
# breakcontinue.ipynb       | 3.6 kb
# builtinstringfun.ipynb    | 2.7 kb
# ControlFlow.ipynb         | 2.6 kb
# count.ipynb               | 1.5 kb
# dictionary.ipynb          | 9.0 kb
# Enumerate.ipynb           | 1.9 kb
# evenodd.ipynb             | 1.0 kb
# File_Handling.ipynb       | 88.1 kb
# forElseLoop.ipynb         | 1.7 kb
# list.ipynb                | 10.6 kb
# Loops.ipynb               | 3.5 kb
# Method2.ipynb             | 2.8 kb
# Methods.ipynb             | 3.7 kb
# os_module.ipynb           | 77.3 kb
# primenumber.ipynb         | 1.1 kb
# pythagorstheorem.ipynb    | 1.0 kb
# range.ipynb               | 3.6 kb
# sample.ipynb              | 1.8 kb
# Sets.ipynb                | 9.9 kb
# simpleInterest.ipynb      | 1.1 kb
# sizeofword.ipynb          | 1.3 kb
# slicingInString.ipynb     | 2.0 kb
# string.ipynb              | 2.0 kb
# String_question.ipynb     | 4.3 kb
# ...

# %% [markdown]
# # Finding the size of random files

# %%
folder = 'C:/Windows/System32/'
files = os.listdir(folder)
for item in files:
    fullpath = os.path.join(folder,item)
    if os.path.isfile(fullpath):
        sz = os.path.getsize(fullpath)
        print(f'{item.ljust(25)} | {sz/1024 :.1f} kb')
# Out:
# @edptoastimage.png        | 0.7 kb
# @language_notification_icon.png | 0.6 kb
# @NotifierToastIcon.png    | 0.5 kb
# @optionalfeatures.png     | 0.6 kb
# @TileEmpty1x1Image.png    | 0.1 kb
# @WiFiNotificationIcon.png | 14.8 kb
# aadauthhelper.dll         | 34.0 kb
# aadcloudap.dll            | 308.0 kb
# aadtb.dll                 | 827.5 kb
# AboveLockAppHost.dll      | 161.0 kb
# accessibilitycpl.dll      | 3724.5 kb
# accountaccessor.dll       | 250.5 kb
# AccountsControlInternal.dll | 15.0 kb
# AccountsRt.dll            | 434.5 kb
# ACCTRES.dll               | 39.5 kb
# acledit.dll               | 10.5 kb
# aclui.dll                 | 5382.0 kb
# acmigration.dll           | 185.8 kb
# ACPBackgroundManagerPolicy.dll | 133.0 kb
# AcpiServiceVnA64.dll      | 115.8 kb
# acppage.dll               | 54.5 kb
# acproxy.dll               | 12.5 kb
# ActionCenter.dll          | 303.5 kb
# ActionCenterCPL.dll       | 552.0 kb
# ActionQueue.dll           | 230.8 kb
# ...

# %% [markdown]
# # Saving data into word file.

# %%
data = ""
folder = 'C:/Windows/System32/'
files = os.listdir(folder)
for item in files:
    fullpath = os.path.join(folder,item)
    if os.path.isfile(fullpath):
        sz = os.path.getsize(fullpath)
        out = f'{item.ljust(25)} | {sz/1024 :.1f} kb'
        print(out)
        data += out +'\n'
# Out:
# @edptoastimage.png        | 0.7 kb
# @language_notification_icon.png | 0.6 kb
# @NotifierToastIcon.png    | 0.5 kb
# @optionalfeatures.png     | 0.6 kb
# @TileEmpty1x1Image.png    | 0.1 kb
# @WiFiNotificationIcon.png | 14.8 kb
# aadauthhelper.dll         | 34.0 kb
# aadcloudap.dll            | 308.0 kb
# aadtb.dll                 | 827.5 kb
# AboveLockAppHost.dll      | 161.0 kb
# accessibilitycpl.dll      | 3724.5 kb
# accountaccessor.dll       | 250.5 kb
# AccountsControlInternal.dll | 15.0 kb
# AccountsRt.dll            | 434.5 kb
# ACCTRES.dll               | 39.5 kb
# acledit.dll               | 10.5 kb
# aclui.dll                 | 5382.0 kb
# acmigration.dll           | 185.8 kb
# ACPBackgroundManagerPolicy.dll | 133.0 kb
# AcpiServiceVnA64.dll      | 115.8 kb
# acppage.dll               | 54.5 kb
# acproxy.dll               | 12.5 kb
# ActionCenter.dll          | 303.5 kb
# ActionCenterCPL.dll       | 552.0 kb
# ActionQueue.dll           | 230.8 kb
# ...

# %%
from dputils import files
files.save_data('dlls.txt',data)
# Out:
# True

# %%
os.mkdir('Function') # mkdir is used to create a folder
